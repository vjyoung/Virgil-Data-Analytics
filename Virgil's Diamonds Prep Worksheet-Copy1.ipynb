# %%
import pandas as pd
import numpy as np

# %%
#load csv file data with headers

location = "datasets/diamonds.csv"
df = pd.read_csv(location)

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail(3)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.iloc[53939]
# Out:
# Unnamed: 0    53940
# carat          0.75
# cut           Ideal
# color             D
# clarity         SI2
# depth          62.2
# table            55
# price          2757
# x              5.83
# y              5.87
# z              3.64
# Name: 53939, dtype: object

# %%
df_max_carat = df.loc[df['carat'] > 5]
df_max_carat
# Out:
#        Unnamed: 0  carat   cut color clarity  depth  table  price      x  \
# 27415       27416   5.01  Fair     J      I1   65.5   59.0  18018  10.74
#
#            y     z
# 27415  10.54  6.98

# %%
#multiple conditions
#multiple conditions
df.sort_values('price', ascending = False)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27747       27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37
# 27746       27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20
# 27745       27746   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95
# 27744       27745   2.29    Premium     I     SI1   61.8   59.0  18797  8.52
# 27742       27743   2.04    Premium     H     SI1   58.1   60.0  18795  8.37
# 27743       27744   2.00    Premium     I     VS1   60.8   59.0  18795  8.13
# 27740       27741   1.71    Premium     F     VS2   62.3   59.0  18791  7.57
# 27741       27742   2.15      Ideal     G     SI2   62.6   54.0  18791  8.29
# 27739       27740   2.80       Good     G     SI2   63.8   58.0  18788  8.90
# ...

# %%
import statsmodels.formula.api as smf

# %%
result = smf.ols('price ~ carat + table + depth', data=df).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 1.049e+05
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):               0.00
# Time:                        09:32:27   Log-Likelihood:            -4.7194e+05
# No. Observations:               53940   AIC:                         9.439e+05
# Df Residuals:                   53936   BIC:                         9.439e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     1.3e+04    390.918     33.264      0.000    1.22e+04    1.38e+04
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.lmplot(x='carat', y='price', data=df)

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn

# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression
X = df.drop('price', axis = 1)

#assign linear regression function to a variable
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X = df.drop(['cut','color','clarity','Unnamed: 0','x','y','z'], axis =1)

# %%
lm.fit(X, df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Estimated intercept coefficient:', lm.intercept_)
# Out:
# Estimated intercept coefficient: 1.44609657582e-10

# %%
print('Number of coefficients:', len(lm.coef_))
# Out:
# Number of coefficients: 4

# %%
pd.DataFrame(list(zip(X.columns, lm.coef_)), columns = ['features', 'estimatedCoefficients'])
# Out:
#   features  estimatedCoefficients
# 0    carat          -2.042506e-10
# 1    depth          -3.198553e-13
# 2    table           3.488348e-13
# 3    price           1.000000e+00

# %%
plt.scatter(df.carat, df.price)
plt.xlabel("Size of carat(carat)") 
plt.ylabel("Diamond Price") 
plt.title("Relationship between Carat Size and Price") 
plt.show()
